# %% [markdown]
# Exercice 1 : Charger et afficher quelques lignes des datasets
#
# a) Charger les datasets "iris.csv" et "titanic_train.csv" en utilisant pandas.
# b) Afficher les cinq premières lignes de chaque dataset.

# %% [markdown]
# Exercice 2 : Nombre de lignes et de colonnes
#
# a) Déterminer le nombre de lignes et de colonnes dans chaque dataset.

# %% [markdown]
# Exercice 3 : Types de données
#
# a) Identifier les types de données de chaque colonne dans les datasets.

# %% [markdown]
# Exercice 4 : Vérification des données manquantes
#
# a) Vérifier s'il manque des données dans chaque dataset.
# b) Compter le nombre de données manquantes dans chaque colonne.

# %% [markdown]
# Exercice 5 : Réalisation d'histogrammes
#
# a) Réaliser des histogrammes pour visualiser la distribution des données dans chaque colonne du dataset "iris.csv".

# %% [markdown]
# Exercice 6 : Réalisation de nuages de points
#
# a) Réaliser des nuages de points pour explorer les relations entre les variables du dataset "iris.csv".

# %% [markdown]
# Exercice 7 : Croisement des données
#
# a) Réaliser un croisement entre deux colonnes du dataset "titanic_train.csv", par exemple entre la classe des passagers et leur survie.
